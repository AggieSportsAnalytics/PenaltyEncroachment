# %%
import cv2
import numpy as np
import torch
import os
from ultralytics import YOLO

# %%
cap = cv2.VideoCapture('./pen.mp4')

# %%
model = YOLO("yolov8m.pt")

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, device="mps")
    result = results[0]
    bboxes = np.array(result.boxes.xyxy.cpu(), dtype="int")
    classes = np.array(result.boxes.cls.cpu(), dtype="int")
    for cls, bbox in zip(classes, bboxes):
        if cls == 0:
            (x, y, x2, y2) = bbox
            cv2.rectangle(frame, (x, y), (x2, y2), (0, 0, 225), 2)
            cv2.putText(frame, "Player", (x, y - 5), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 225), 2)
        if cls == 32:
            (x, y, x2, y2) = bbox
            cv2.rectangle(frame, (x, y), (x2, y2), (0, 0, 225), 2)
            cv2.putText(frame, "Ball", (x, y - 5), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 225), 2)

    tl = (250, 1070)
    bl = (1450, 1400) 
    tr = (1350, 760)
    br = (2650, 920) 

    cv2.circle(frame, tl, 5, (255, 0, 0), -1) 
    cv2.circle(frame, bl, 5, (255, 0, 0), -1)
    cv2.circle(frame, tr, 5, (255, 0, 0), -1)
    cv2.circle(frame, br, 5, (255, 0, 0), -1)

    pts1 = np.float32([tl, bl, tr, br])
    pts2 = np.float32([[0,0], [0,1570], [2912, 0], [2912, 1570]])

    matrix = cv2.getPerspectiveTransform(pts1, pts2)
    transformed_frame = cv2.warpPerspective(frame, matrix, (640, 480))

    cv2.imshow("Img", frame)
    cv2.imshow("transformed_frame Bird's Eye View", transformed_frame)

    key = cv2.waitKey(1)
    if key == 27 or cv2.getWindowProperty("Img", cv2.WND_PROP_VISIBLE) < 1:
        break

        
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(0)
# Out:
# 0: 352x640 12 persons, 1 sports ball, 327.0ms
# Speed: 16.3ms preprocess, 327.0ms inference, 42.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 46.1ms
# Speed: 2.6ms preprocess, 46.1ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.8ms
# Speed: 5.7ms preprocess, 41.8ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 26.3ms
# Speed: 2.5ms preprocess, 26.3ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.4ms
# Speed: 2.4ms preprocess, 41.4ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 24.0ms
# Speed: 2.6ms preprocess, 24.0ms inference, 17.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.3ms
# Speed: 2.4ms preprocess, 41.3ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 45.0ms
# Speed: 2.3ms preprocess, 45.0ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.7ms
# Speed: 2.4ms preprocess, 37.7ms inference, 18.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.7ms
# Speed: 2.5ms preprocess, 37.7ms inference, 14.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.2ms
# Speed: 2.4ms preprocess, 41.2ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.2ms
# Speed: 2.4ms preprocess, 41.2ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.5ms
# Speed: 2.3ms preprocess, 37.5ms inference, 19.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.5ms
# Speed: 2.4ms preprocess, 37.5ms inference, 22.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 34.4ms
# Speed: 2.3ms preprocess, 34.4ms inference, 18.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.7ms
# Speed: 2.4ms preprocess, 36.7ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.7ms
# Speed: 2.5ms preprocess, 40.7ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.5ms
# Speed: 2.6ms preprocess, 38.5ms inference, 17.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.3ms
# Speed: 2.4ms preprocess, 41.3ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.0ms
# Speed: 2.9ms preprocess, 38.0ms inference, 19.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.7ms
# Speed: 2.5ms preprocess, 36.7ms inference, 16.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 11.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 42.8ms
# Speed: 2.5ms preprocess, 42.8ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 23.4ms
# Speed: 2.4ms preprocess, 23.4ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.7ms
# Speed: 2.4ms preprocess, 41.7ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 22.7ms
# Speed: 2.6ms preprocess, 22.7ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 28.3ms
# Speed: 2.3ms preprocess, 28.3ms inference, 17.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 35.8ms
# Speed: 2.5ms preprocess, 35.8ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 23.6ms
# Speed: 2.3ms preprocess, 23.6ms inference, 14.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 43.8ms
# Speed: 2.5ms preprocess, 43.8ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 23.3ms
# Speed: 2.4ms preprocess, 23.3ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 31.7ms
# Speed: 2.3ms preprocess, 31.7ms inference, 20.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 33.6ms
# Speed: 2.5ms preprocess, 33.6ms inference, 19.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.9ms
# Speed: 2.4ms preprocess, 36.9ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 39.4ms
# Speed: 2.3ms preprocess, 39.4ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.5ms
# Speed: 2.4ms preprocess, 40.5ms inference, 10.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.8ms
# Speed: 2.6ms preprocess, 37.8ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.6ms
# Speed: 2.4ms preprocess, 36.6ms inference, 24.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 33.5ms
# Speed: 2.2ms preprocess, 33.5ms inference, 19.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.0ms
# Speed: 2.7ms preprocess, 36.0ms inference, 24.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 32.7ms
# Speed: 2.4ms preprocess, 32.7ms inference, 20.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 33.8ms
# Speed: 2.3ms preprocess, 33.8ms inference, 19.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 35.9ms
# Speed: 2.5ms preprocess, 35.9ms inference, 16.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.9ms
# Speed: 2.3ms preprocess, 38.9ms inference, 21.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.7ms
# Speed: 2.4ms preprocess, 30.7ms inference, 18.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 29.4ms
# Speed: 2.3ms preprocess, 29.4ms inference, 19.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 34.1ms
# Speed: 2.5ms preprocess, 34.1ms inference, 18.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.2ms
# Speed: 2.5ms preprocess, 37.2ms inference, 15.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 11.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.6ms
# Speed: 2.3ms preprocess, 37.6ms inference, 18.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.1ms
# Speed: 2.3ms preprocess, 30.1ms inference, 20.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.1ms
# Speed: 2.3ms preprocess, 36.1ms inference, 24.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 33.2ms
# Speed: 2.5ms preprocess, 33.2ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 35.0ms
# Speed: 2.3ms preprocess, 35.0ms inference, 18.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.1ms
# Speed: 2.4ms preprocess, 38.1ms inference, 22.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 33.1ms
# Speed: 2.3ms preprocess, 33.1ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.6ms
# Speed: 2.2ms preprocess, 30.6ms inference, 19.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.1ms
# Speed: 2.4ms preprocess, 30.1ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.1ms
# Speed: 2.5ms preprocess, 30.1ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.3ms
# Speed: 2.4ms preprocess, 38.3ms inference, 22.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 32.9ms
# Speed: 2.3ms preprocess, 32.9ms inference, 19.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 29.5ms
# Speed: 2.3ms preprocess, 29.5ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 34.7ms
# Speed: 2.2ms preprocess, 34.7ms inference, 18.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 42.6ms
# Speed: 2.4ms preprocess, 42.6ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.2ms
# Speed: 2.3ms preprocess, 37.2ms inference, 19.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.1ms
# Speed: 2.5ms preprocess, 36.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 24.9ms
# Speed: 2.4ms preprocess, 24.9ms inference, 17.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.8ms
# Speed: 2.4ms preprocess, 40.8ms inference, 15.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.2ms
# Speed: 2.4ms preprocess, 41.2ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 38.2ms
# Speed: 2.3ms preprocess, 38.2ms inference, 18.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.6ms
# Speed: 2.3ms preprocess, 36.6ms inference, 15.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.0ms
# Speed: 2.4ms preprocess, 40.0ms inference, 12.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 42.0ms
# Speed: 2.5ms preprocess, 42.0ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.9ms
# Speed: 2.4ms preprocess, 37.9ms inference, 18.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 39.3ms
# Speed: 2.3ms preprocess, 39.3ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 31.9ms
# Speed: 2.8ms preprocess, 31.9ms inference, 20.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 29.7ms
# Speed: 2.3ms preprocess, 29.7ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.2ms
# Speed: 2.4ms preprocess, 30.2ms inference, 19.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 34.5ms
# Speed: 2.3ms preprocess, 34.5ms inference, 18.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 12.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 41.5ms
# Speed: 2.3ms preprocess, 41.5ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.5ms
# Speed: 2.8ms preprocess, 37.5ms inference, 19.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 17.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 39.7ms
# Speed: 2.4ms preprocess, 39.7ms inference, 21.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 30.2ms
# Speed: 2.4ms preprocess, 30.2ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 37.2ms
# Speed: 2.3ms preprocess, 37.2ms inference, 23.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 34.5ms
# Speed: 2.4ms preprocess, 34.5ms inference, 18.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 36.8ms
# Speed: 2.5ms preprocess, 36.8ms inference, 15.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 42.1ms
# Speed: 2.4ms preprocess, 42.1ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 12 persons, 1 sports ball, 40.4ms
# Speed: 2.4ms preprocess, 40.4ms inference, 14.7ms postprocess per image at shape (1, 3, 640, 640)
